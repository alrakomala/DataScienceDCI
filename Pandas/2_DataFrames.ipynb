# %% [markdown]
# ## **DataFrame:**
#
# Estructura (objeto) multivariable con indexación integrada. _Tabla_
#
# Conjunto de Series

# %%
import pandas as pd
import numpy as np

# %%
valores = [['Ana', 18, 0.5], ['Luis', 22, 0.33], ['Carmen', 20, 0.85]]
columnas = ['Nombre', 'Edad', 'Otro']
filas = ['a', 'b', 'c']

df = pd.DataFrame(data=valores, index=filas, columns=columnas)
df
# Out:
#    Nombre  Edad  Otro
# a     Ana    18  0.50
# b    Luis    22  0.33
# c  Carmen    20  0.85

# %%
nums = np.random.randint(100, 3000, (20, 4))
letters = np.reshape(list("abcd")*5, (20,1))

values = np.append(nums, letters, axis = 1)
values
# Out:
# array([['1311', '1630', '2886', '690', 'a'],
#        ['2630', '361', '1173', '1733', 'b'],
#        ['1594', '867', '1291', '267', 'c'],
#        ['1003', '2034', '565', '2123', 'd'],
#        ['792', '1764', '1824', '1370', 'a'],
#        ['1517', '2741', '1542', '280', 'b'],
#        ['364', '688', '1386', '1535', 'c'],
#        ['975', '622', '683', '2108', 'd'],
#        ['2482', '1064', '916', '286', 'a'],
#        ['922', '2611', '1351', '516', 'b'],
#        ['226', '923', '786', '1579', 'c'],
#        ['1821', '2368', '2981', '2582', 'd'],
#        ['1793', '142', '1662', '785', 'a'],
#        ['2925', '194', '1932', '712', 'b'],
#        ['1830', '814', '2930', '2832', 'c'],
#        ['588', '1793', '2870', '2800', 'd'],
#        ['2787', '1832', '617', '714', 'a'],
#        ['851', '1460', '870', '2438', 'b'],
#        ['2605', '798', '531', '381', 'c'],
#        ['1240', '2253', '2504', '2340', 'd']], dtype='<U21')

# %% [markdown]
# [pandas.date_range](https://pandas.pydata.org/docs/reference/api/pandas.date_range.html)

# %%
fecha = pd.date_range("20230915", periods=20)

# %%
df = pd.DataFrame(values, index=fecha, columns=list("VWXYZ"))
df
# Out:
#                V     W     X     Y  Z
# 2023-09-15  1311  1630  2886   690  a
# 2023-09-16  2630   361  1173  1733  b
# 2023-09-17  1594   867  1291   267  c
# 2023-09-18  1003  2034   565  2123  d
# 2023-09-19   792  1764  1824  1370  a
# 2023-09-20  1517  2741  1542   280  b
# 2023-09-21   364   688  1386  1535  c
# 2023-09-22   975   622   683  2108  d
# 2023-09-23  2482  1064   916   286  a
# 2023-09-24   922  2611  1351   516  b
# 2023-09-25   226   923   786  1579  c
# 2023-09-26  1821  2368  2981  2582  d
# 2023-09-27  1793   142  1662   785  a
# 2023-09-28  2925   194  1932   712  b
# 2023-09-29  1830   814  2930  2832  c
# 2023-09-30   588  1793  2870  2800  d
# 2023-10-01  2787  1832   617   714  a
# 2023-10-02   851  1460   870  2438  b
# 2023-10-03  2605   798   531   381  c
# 2023-10-04  1240  2253  2504  2340  d

# %% [markdown]
# ## acceder a los elementos por índice (DateTime)
#
# Al igual que con las series, se pueden seleccionar elementos por índice o valor/valores

# %%
df['2023-09-26':'2023-09-30']
# Out:
#                V     W     X     Y  Z
# 2023-09-26  1821  2368  2981  2582  d
# 2023-09-27  1793   142  1662   785  a
# 2023-09-28  2925   194  1932   712  b
# 2023-09-29  1830   814  2930  2832  c
# 2023-09-30   588  1793  2870  2800  d

# %%
#df['2023-09-26']  #error

# %%
df.loc['2023-09-26']
# Out:
# V    1821
# W    2368
# X    2981
# Y    2582
# Z       d
# Name: 2023-09-26 00:00:00, dtype: object

# %%
df.loc['2023-09-26':'2023-09-30']
# Out:
#                V     W     X     Y  Z
# 2023-09-26  1821  2368  2981  2582  d
# 2023-09-27  1793   142  1662   785  a
# 2023-09-28  2925   194  1932   712  b
# 2023-09-29  1830   814  2930  2832  c
# 2023-09-30   588  1793  2870  2800  d

# %%
df.iloc[3]
# Out:
# V    1003
# W    2034
# X     565
# Y    2123
# Z       d
# Name: 2023-09-18 00:00:00, dtype: object

# %%
df['W']
# Out:
# 2023-09-15    1630
# 2023-09-16     361
# 2023-09-17     867
# 2023-09-18    2034
# 2023-09-19    1764
# 2023-09-20    2741
# 2023-09-21     688
# 2023-09-22     622
# 2023-09-23    1064
# 2023-09-24    2611
# 2023-09-25     923
# 2023-09-26    2368
# 2023-09-27     142
# 2023-09-28     194
# 2023-09-29     814
# 2023-09-30    1793
# 2023-10-01    1832
# 2023-10-02    1460
# 2023-10-03     798
# 2023-10-04    2253
# Freq: D, Name: W, dtype: object

# %%
df[['W','Z']]
# Out:
#                W  Z
# 2023-09-15  1630  a
# 2023-09-16   361  b
# 2023-09-17   867  c
# 2023-09-18  2034  d
# 2023-09-19  1764  a
# 2023-09-20  2741  b
# 2023-09-21   688  c
# 2023-09-22   622  d
# 2023-09-23  1064  a
# 2023-09-24  2611  b
# 2023-09-25   923  c
# 2023-09-26  2368  d
# 2023-09-27   142  a
# 2023-09-28   194  b
# 2023-09-29   814  c
# 2023-09-30  1793  d
# 2023-10-01  1832  a
# 2023-10-02  1460  b
# 2023-10-03   798  c
# 2023-10-04  2253  d

# %%
df.loc['2023-09-26','Y'] #seleccionar por índice y columna
# Out:
# '2582'

# %%
df.loc['2023-09-26':'2023-09-30',['W','Y']]
# Out:
#                W     Y
# 2023-09-26  2368  2582
# 2023-09-27   142   785
# 2023-09-28   194   712
# 2023-09-29   814  2832
# 2023-09-30  1793  2800

# %%
df.loc[['2023-09-26','2023-09-30'], ['W','Z']]
# Out:
#                W  Z
# 2023-09-26  2368  d
# 2023-09-30  1793  d

# %%
df[['W','Z']].iloc[0:5]
# Out:
#                W  Z
# 2023-09-15  1630  a
# 2023-09-16   361  b
# 2023-09-17   867  c
# 2023-09-18  2034  d
# 2023-09-19  1764  a

# %%
df[['W','Z']].loc[['2023-09-26','2023-09-30']]
# Out:
#                W  Z
# 2023-09-26  2368  d
# 2023-09-30  1793  d

# %% [markdown]
# ## Exploración de los datos

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# V    object
# W    object
# X    object
# Y    object
# Z    object
# dtype: object

# %%
df.columns
# Out:
# Index(['V', 'W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2023-09-15', '2023-09-16', '2023-09-17', '2023-09-18',
#                '2023-09-19', '2023-09-20', '2023-09-21', '2023-09-22',
#                '2023-09-23', '2023-09-24', '2023-09-25', '2023-09-26',
#                '2023-09-27', '2023-09-28', '2023-09-29', '2023-09-30',
#                '2023-10-01', '2023-10-02', '2023-10-03', '2023-10-04'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.head(3) #primeras filas
# Out:
#                V     W     X     Y  Z
# 2023-09-15  1311  1630  2886   690  a
# 2023-09-16  2630   361  1173  1733  b
# 2023-09-17  1594   867  1291   267  c

# %%
df.tail(3) #últimas filas
# Out:
#                V     W     X     Y  Z
# 2023-10-02   851  1460   870  2438  b
# 2023-10-03  2605   798   531   381  c
# 2023-10-04  1240  2253  2504  2340  d

# %%
df.sample(3) # seleccion aleatoria
# Out:
#                V     W     X     Y  Z
# 2023-09-26  1821  2368  2981  2582  d
# 2023-09-18  1003  2034   565  2123  d
# 2023-10-04  1240  2253  2504  2340  d

# %%
df.describe()
# Out:
#            V     W     X    Y   Z
# count     20    20    20   20  20
# unique    20    20    20   20   4
# top     1311  1630  2886  690   a
# freq       1     1     1    1   5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20 entries, 2023-09-15 to 2023-10-04
# Freq: D
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V       20 non-null     object
#  1   W       20 non-null     object
#  2   X       20 non-null     object
#  3   Y       20 non-null     object
#  4   Z       20 non-null     object
# dtypes: object(5)
# memory usage: 1.5+ KB

# %% [markdown]
# ## Añadir y eliminar filas/columnas

# %%
df['new_col'] = 2*df['W'] + df['Y']
df.head()
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-15  1311  1630  2886   690  a   16301630690
# 2023-09-16  2630   361  1173  1733  b    3613611733
# 2023-09-17  1594   867  1291   267  c     867867267
# 2023-09-18  1003  2034   565  2123  d  203420342123
# 2023-09-19   792  1764  1824  1370  a  176417641370

# %%
#df.append(df)
pd.concat([df, df])
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-15  1311  1630  2886   690  a   16301630690
# 2023-09-16  2630   361  1173  1733  b    3613611733
# 2023-09-17  1594   867  1291   267  c     867867267
# 2023-09-18  1003  2034   565  2123  d  203420342123
# 2023-09-19   792  1764  1824  1370  a  176417641370
# 2023-09-20  1517  2741  1542   280  b   27412741280
# 2023-09-21   364   688  1386  1535  c    6886881535
# 2023-09-22   975   622   683  2108  d    6226222108
# 2023-09-23  2482  1064   916   286  a   10641064286
# 2023-09-24   922  2611  1351   516  b   26112611516
# 2023-09-25   226   923   786  1579  c    9239231579
# 2023-09-26  1821  2368  2981  2582  d  236823682582
# 2023-09-27  1793   142  1662   785  a     142142785
# 2023-09-28  2925   194  1932   712  b     194194712
# 2023-09-29  1830   814  2930  2832  c    8148142832
# 2023-09-30   588  1793  2870  2800  d  179317932800
# 2023-10-01  2787  1832   617   714  a   18321832714
# ...

# %%
pd.concat([df, df], ignore_index = True)
# Out:
#        V     W     X     Y  Z       new_col
# 0   1311  1630  2886   690  a   16301630690
# 1   2630   361  1173  1733  b    3613611733
# 2   1594   867  1291   267  c     867867267
# 3   1003  2034   565  2123  d  203420342123
# 4    792  1764  1824  1370  a  176417641370
# 5   1517  2741  1542   280  b   27412741280
# 6    364   688  1386  1535  c    6886881535
# 7    975   622   683  2108  d    6226222108
# 8   2482  1064   916   286  a   10641064286
# 9    922  2611  1351   516  b   26112611516
# 10   226   923   786  1579  c    9239231579
# 11  1821  2368  2981  2582  d  236823682582
# 12  1793   142  1662   785  a     142142785
# 13  2925   194  1932   712  b     194194712
# 14  1830   814  2930  2832  c    8148142832
# 15   588  1793  2870  2800  d  179317932800
# 16  2787  1832   617   714  a   18321832714
# 17   851  1460   870  2438  b  146014602438
# 18  2605   798   531   381  c     798798381
# 19  1240  2253  2504  2340  d  225322532340
# ...

# %%
df
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-15  1311  1630  2886   690  a   16301630690
# 2023-09-16  2630   361  1173  1733  b    3613611733
# 2023-09-17  1594   867  1291   267  c     867867267
# 2023-09-18  1003  2034   565  2123  d  203420342123
# 2023-09-19   792  1764  1824  1370  a  176417641370
# 2023-09-20  1517  2741  1542   280  b   27412741280
# 2023-09-21   364   688  1386  1535  c    6886881535
# 2023-09-22   975   622   683  2108  d    6226222108
# 2023-09-23  2482  1064   916   286  a   10641064286
# 2023-09-24   922  2611  1351   516  b   26112611516
# 2023-09-25   226   923   786  1579  c    9239231579
# 2023-09-26  1821  2368  2981  2582  d  236823682582
# 2023-09-27  1793   142  1662   785  a     142142785
# 2023-09-28  2925   194  1932   712  b     194194712
# 2023-09-29  1830   814  2930  2832  c    8148142832
# 2023-09-30   588  1793  2870  2800  d  179317932800
# 2023-10-01  2787  1832   617   714  a   18321832714
# ...

# %%
df.drop('2023-09-26') #default: axis = 0
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-15  1311  1630  2886   690  a   16301630690
# 2023-09-16  2630   361  1173  1733  b    3613611733
# 2023-09-17  1594   867  1291   267  c     867867267
# 2023-09-18  1003  2034   565  2123  d  203420342123
# 2023-09-19   792  1764  1824  1370  a  176417641370
# 2023-09-20  1517  2741  1542   280  b   27412741280
# 2023-09-21   364   688  1386  1535  c    6886881535
# 2023-09-22   975   622   683  2108  d    6226222108
# 2023-09-23  2482  1064   916   286  a   10641064286
# 2023-09-24   922  2611  1351   516  b   26112611516
# 2023-09-25   226   923   786  1579  c    9239231579
# 2023-09-27  1793   142  1662   785  a     142142785
# 2023-09-28  2925   194  1932   712  b     194194712
# 2023-09-29  1830   814  2930  2832  c    8148142832
# 2023-09-30   588  1793  2870  2800  d  179317932800
# 2023-10-01  2787  1832   617   714  a   18321832714
# 2023-10-02   851  1460   870  2438  b  146014602438
# ...

# %%
df.drop('2023-09-15', axis=0)
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-16  2630   361  1173  1733  b    3613611733
# 2023-09-17  1594   867  1291   267  c     867867267
# 2023-09-18  1003  2034   565  2123  d  203420342123
# 2023-09-19   792  1764  1824  1370  a  176417641370
# 2023-09-20  1517  2741  1542   280  b   27412741280
# 2023-09-21   364   688  1386  1535  c    6886881535
# 2023-09-22   975   622   683  2108  d    6226222108
# 2023-09-23  2482  1064   916   286  a   10641064286
# 2023-09-24   922  2611  1351   516  b   26112611516
# 2023-09-25   226   923   786  1579  c    9239231579
# 2023-09-26  1821  2368  2981  2582  d  236823682582
# 2023-09-27  1793   142  1662   785  a     142142785
# 2023-09-28  2925   194  1932   712  b     194194712
# 2023-09-29  1830   814  2930  2832  c    8148142832
# 2023-09-30   588  1793  2870  2800  d  179317932800
# 2023-10-01  2787  1832   617   714  a   18321832714
# 2023-10-02   851  1460   870  2438  b  146014602438
# ...

# %%
df.head()
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-15  1311  1630  2886   690  a   16301630690
# 2023-09-16  2630   361  1173  1733  b    3613611733
# 2023-09-17  1594   867  1291   267  c     867867267
# 2023-09-18  1003  2034   565  2123  d  203420342123
# 2023-09-19   792  1764  1824  1370  a  176417641370

# %%
df.drop('new_col',axis=1) # para eliminar columnas axis = 1
# Out:
#                V     W     X     Y  Z
# 2023-09-15  1311  1630  2886   690  a
# 2023-09-16  2630   361  1173  1733  b
# 2023-09-17  1594   867  1291   267  c
# 2023-09-18  1003  2034   565  2123  d
# 2023-09-19   792  1764  1824  1370  a
# 2023-09-20  1517  2741  1542   280  b
# 2023-09-21   364   688  1386  1535  c
# 2023-09-22   975   622   683  2108  d
# 2023-09-23  2482  1064   916   286  a
# 2023-09-24   922  2611  1351   516  b
# 2023-09-25   226   923   786  1579  c
# 2023-09-26  1821  2368  2981  2582  d
# 2023-09-27  1793   142  1662   785  a
# 2023-09-28  2925   194  1932   712  b
# 2023-09-29  1830   814  2930  2832  c
# 2023-09-30   588  1793  2870  2800  d
# 2023-10-01  2787  1832   617   714  a
# 2023-10-02   851  1460   870  2438  b
# 2023-10-03  2605   798   531   381  c
# 2023-10-04  1240  2253  2504  2340  d

# %%
df.head()
# Out:
#                V     W     X     Y  Z       new_col
# 2023-09-15  1311  1630  2886   690  a   16301630690
# 2023-09-16  2630   361  1173  1733  b    3613611733
# 2023-09-17  1594   867  1291   267  c     867867267
# 2023-09-18  1003  2034   565  2123  d  203420342123
# 2023-09-19   792  1764  1824  1370  a  176417641370

# %%
df.drop('new_col',axis=1, inplace=True) # para guardar el cambio

# %%
df.head()
# Out:
#                V     W     X     Y  Z
# 2023-09-15  1311  1630  2886   690  a
# 2023-09-16  2630   361  1173  1733  b
# 2023-09-17  1594   867  1291   267  c
# 2023-09-18  1003  2034   565  2123  d
# 2023-09-19   792  1764  1824  1370  a

# %%
df.drop(columns=['V', 'Y'])
# Out:
#                W     X  Z
# 2023-09-15  1630  2886  a
# 2023-09-16   361  1173  b
# 2023-09-17   867  1291  c
# 2023-09-18  2034   565  d
# 2023-09-19  1764  1824  a
# 2023-09-20  2741  1542  b
# 2023-09-21   688  1386  c
# 2023-09-22   622   683  d
# 2023-09-23  1064   916  a
# 2023-09-24  2611  1351  b
# 2023-09-25   923   786  c
# 2023-09-26  2368  2981  d
# 2023-09-27   142  1662  a
# 2023-09-28   194  1932  b
# 2023-09-29   814  2930  c
# 2023-09-30  1793  2870  d
# 2023-10-01  1832   617  a
# 2023-10-02  1460   870  b
# 2023-10-03   798   531  c
# 2023-10-04  2253  2504  d

# %% [markdown]
# ## Operaciones y manipulación

# %%
df.sort_index(ascending=False)
# Out:
#                V     W     X     Y  Z
# 2023-10-04  1240  2253  2504  2340  d
# 2023-10-03  2605   798   531   381  c
# 2023-10-02   851  1460   870  2438  b
# 2023-10-01  2787  1832   617   714  a
# 2023-09-30   588  1793  2870  2800  d
# 2023-09-29  1830   814  2930  2832  c
# 2023-09-28  2925   194  1932   712  b
# 2023-09-27  1793   142  1662   785  a
# 2023-09-26  1821  2368  2981  2582  d
# 2023-09-25   226   923   786  1579  c
# 2023-09-24   922  2611  1351   516  b
# 2023-09-23  2482  1064   916   286  a
# 2023-09-22   975   622   683  2108  d
# 2023-09-21   364   688  1386  1535  c
# 2023-09-20  1517  2741  1542   280  b
# 2023-09-19   792  1764  1824  1370  a
# 2023-09-18  1003  2034   565  2123  d
# 2023-09-17  1594   867  1291   267  c
# 2023-09-16  2630   361  1173  1733  b
# 2023-09-15  1311  1630  2886   690  a

# %%
df.sort_values(by=['V'], ascending = True)  #no funciona
# Out:
#                V     W     X     Y  Z
# 2023-09-18  1003  2034   565  2123  d
# 2023-10-04  1240  2253  2504  2340  d
# 2023-09-15  1311  1630  2886   690  a
# 2023-09-20  1517  2741  1542   280  b
# 2023-09-17  1594   867  1291   267  c
# 2023-09-27  1793   142  1662   785  a
# 2023-09-26  1821  2368  2981  2582  d
# 2023-09-29  1830   814  2930  2832  c
# 2023-09-25   226   923   786  1579  c
# 2023-09-23  2482  1064   916   286  a
# 2023-10-03  2605   798   531   381  c
# 2023-09-16  2630   361  1173  1733  b
# 2023-10-01  2787  1832   617   714  a
# 2023-09-28  2925   194  1932   712  b
# 2023-09-21   364   688  1386  1535  c
# 2023-09-30   588  1793  2870  2800  d
# 2023-09-19   792  1764  1824  1370  a
# 2023-10-02   851  1460   870  2438  b
# 2023-09-24   922  2611  1351   516  b
# 2023-09-22   975   622   683  2108  d

# %%
cambiar_tipo = {
    'V': 'int64',
    'W': 'int64' }

df = df.astype(cambiar_tipo)

# %%
df.dtypes
# Out:
# V     int64
# W     int64
# X    object
# Y    object
# Z    object
# dtype: object

# %%
df.sort_values(by=['V'], ascending = False)
# Out:
#                V     W     X     Y  Z
# 2023-09-28  2925   194  1932   712  b
# 2023-10-01  2787  1832   617   714  a
# 2023-09-16  2630   361  1173  1733  b
# 2023-10-03  2605   798   531   381  c
# 2023-09-23  2482  1064   916   286  a
# 2023-09-29  1830   814  2930  2832  c
# 2023-09-26  1821  2368  2981  2582  d
# 2023-09-27  1793   142  1662   785  a
# 2023-09-17  1594   867  1291   267  c
# 2023-09-20  1517  2741  1542   280  b
# 2023-09-15  1311  1630  2886   690  a
# 2023-10-04  1240  2253  2504  2340  d
# 2023-09-18  1003  2034   565  2123  d
# 2023-09-22   975   622   683  2108  d
# 2023-09-24   922  2611  1351   516  b
# 2023-10-02   851  1460   870  2438  b
# 2023-09-19   792  1764  1824  1370  a
# 2023-09-30   588  1793  2870  2800  d
# 2023-09-21   364   688  1386  1535  c
# 2023-09-25   226   923   786  1579  c

# %%
df.reset_index(inplace = True)
df
# Out:
#         index     V     W     X     Y  Z
# 0  2023-09-15  1311  1630  2886   690  a
# 1  2023-09-16  2630   361  1173  1733  b
# 2  2023-09-17  1594   867  1291   267  c
# 3  2023-09-18  1003  2034   565  2123  d
# 4  2023-09-19   792  1764  1824  1370  a
# 5  2023-09-20  1517  2741  1542   280  b
# 6  2023-09-21   364   688  1386  1535  c
# 7  2023-09-22   975   622   683  2108  d
# 8  2023-09-23  2482  1064   916   286  a
# 9  2023-09-24   922  2611  1351   516  b
# 10 2023-09-25   226   923   786  1579  c
# 11 2023-09-26  1821  2368  2981  2582  d
# 12 2023-09-27  1793   142  1662   785  a
# 13 2023-09-28  2925   194  1932   712  b
# 14 2023-09-29  1830   814  2930  2832  c
# 15 2023-09-30   588  1793  2870  2800  d
# 16 2023-10-01  2787  1832   617   714  a
# 17 2023-10-02   851  1460   870  2438  b
# 18 2023-10-03  2605   798   531   381  c
# 19 2023-10-04  1240  2253  2504  2340  d

# %%
df.set_index('Z', inplace = True)

# %%
df.head()
# Out:
#        index     V     W     X     Y
# Z
# a 2023-09-15  1311  1630  2886   690
# b 2023-09-16  2630   361  1173  1733
# c 2023-09-17  1594   867  1291   267
# d 2023-09-18  1003  2034   565  2123
# a 2023-09-19   792  1764  1824  1370

# %%
df.dtypes
# Out:
# index    datetime64[ns]
# V                 int64
# W                 int64
# X                object
# Y                object
# dtype: object

# %% [markdown]
# ### Filtrando elementos

# %%
df[['V', 'W']] > 1000
# Out:
#        V      W
# Z
# a   True   True
# b   True  False
# c   True  False
# d   True   True
# a  False   True
# b   True   True
# c  False  False
# d  False  False
# a   True   True
# b  False   True
# c  False  False
# d   True   True
# a   True  False
# b   True  False
# c   True  False
# d  False   True
# a   True   True
# b  False   True
# c   True  False
# d   True   True

# %%
df[df['W'] > 1000]
# Out:
#        index     V     W     X     Y
# Z
# a 2023-09-15  1311  1630  2886   690
# d 2023-09-18  1003  2034   565  2123
# a 2023-09-19   792  1764  1824  1370
# b 2023-09-20  1517  2741  1542   280
# a 2023-09-23  2482  1064   916   286
# b 2023-09-24   922  2611  1351   516
# d 2023-09-26  1821  2368  2981  2582
# d 2023-09-30   588  1793  2870  2800
# a 2023-10-01  2787  1832   617   714
# b 2023-10-02   851  1460   870  2438
# d 2023-10-04  1240  2253  2504  2340

# %%
df[df['W'] > 1000][['X', 'V']]
# Out:
#       X     V
# Z
# a  2886  1311
# d   565  1003
# a  1824   792
# b  1542  1517
# a   916  2482
# b  1351   922
# d  2981  1821
# d  2870   588
# a   617  2787
# b   870   851
# d  2504  1240

# %%
df[df['W'] > 0][['Y','X']]
# Out:
#       Y     X
# Z
# a   690  2886
# b  1733  1173
# c   267  1291
# d  2123   565
# a  1370  1824
# b   280  1542
# c  1535  1386
# d  2108   683
# a   286   916
# b   516  1351
# c  1579   786
# d  2582  2981
# a   785  1662
# b   712  1932
# c  2832  2930
# d  2800  2870
# a   714   617
# b  2438   870
# c   381   531
# d  2340  2504

# %%
df[(df['W'] <= 1500) & (df['V'] > 1000)]
# Out:
#        index     V     W     X     Y
# Z
# b 2023-09-16  2630   361  1173  1733
# c 2023-09-17  1594   867  1291   267
# a 2023-09-23  2482  1064   916   286
# a 2023-09-27  1793   142  1662   785
# b 2023-09-28  2925   194  1932   712
# c 2023-09-29  1830   814  2930  2832
# c 2023-10-03  2605   798   531   381

# %%
df2 = df[(df['W'] <= 1500) & (df['V'] > 1000)]

df2
# Out:
#        index     V     W     X     Y
# Z
# b 2023-09-16  2630   361  1173  1733
# c 2023-09-17  1594   867  1291   267
# a 2023-09-23  2482  1064   916   286
# a 2023-09-27  1793   142  1662   785
# b 2023-09-28  2925   194  1932   712
# c 2023-09-29  1830   814  2930  2832
# c 2023-10-03  2605   798   531   381

# %%
df2.loc['d']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ...

# %%
# Renombrar columnas:

df2 = df2.rename(columns={'index':'Fecha', 'V':'numero_eventos', 'Y':'masa'})
df2.head()

# %% [markdown]
# ## Lectura/escritura de archivos csv, JSON
#
# [read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html#pandas.read_csv)
#
# [to_csv](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html)

# %%
df2.to_csv('prueba.csv', sep=',')

# %%
df2.to_csv('prueba.csv', sep=',', index=False)

# %%
df = pd.read_csv('prueba.csv')

# %%
df.head()

# %%
df2.to_csv('prueba.csv', sep=',')
df = pd.read_csv('prueba.csv')
df.head()

# %%
df = pd.read_csv('prueba.csv', index_col = 'Z')
df.head()
